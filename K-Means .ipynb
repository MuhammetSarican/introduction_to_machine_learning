# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% create dataset

# class1
x1 = np.random.normal(25,5,1000)
y1 = np.random.normal(25,5,1000)

# class2
x2 = np.random.normal(55,5,1000)
y2 = np.random.normal(60,5,1000)

# x4 = np.random.normal(25,5,1000)
# y4 = np.random.normal(70,5,1000)

# class3
x3 = np.random.normal(55,5,1000)
y3 = np.random.normal(15,5,1000)

# %%
x = np.concatenate((x1,x2,x3),axis = 0)
y = np.concatenate((y1,y2,y3),axis = 0)

# %%
dictionary = {"x":x,"y":y}

data = pd.DataFrame(dictionary)

# plt.subplot(2,1,2)
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.scatter(x3,y3)

plt.show()

# plt.subplot(2,1,2)

# # %% kmeans algoritması bunu gorecek
# plt.scatter(x1,y1,color = "black")
# plt.scatter(x2,y2,color = "black")
# plt.scatter(x3,y3,color = "black")
# plt.show()

# %%
# %% KMEANS

from sklearn.cluster import KMeans
wcss = []

for k in range(1,15):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,15),wcss)
plt.xlabel("number of k (cluster) value")
plt.ylabel("wcss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [61], in <cell line: 6>()
#       6 for k in range(1,15):
#       7     kmeans = KMeans(n_clusters=k)
# ----> 8     kmeans.fit(data)
#       9     wcss.append(kmeans.inertia_)
#      11 plt.plot(range(1,15),wcss)
#
# File D:\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1186, in KMeans.fit(self, X, y, sample_weight)
#    1183     print("Initialization complete")
#    1185 # run a k-means once
# -> 1186 labels, inertia, centers, n_iter_ = kmeans_single(
#    1187     X,
#    1188     sample_weight,
#    1189     centers_init,
#    1190     max_iter=self.max_iter,
#    1191     verbose=self.verbose,
#    1192     tol=self._tol,
#    1193     x_squared_norms=x_squared_norms,
#    1194     n_threads=self._n_threads,
#    1195 )
#    1197 # determine if these results are the best so far
# ...

# %%
#%% k = 3 icin modelim

kmeans2 = KMeans(n_clusters=1)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [62], in <cell line: 4>()
#       1 #%% k = 3 icin modelim
#       3 kmeans2 = KMeans(n_clusters=1)
# ----> 4 clusters = kmeans2.fit_predict(data)
#       6 data["label"] = clusters
#       8 plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")
#
# File D:\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1255, in KMeans.fit_predict(self, X, y, sample_weight)
#    1232 def fit_predict(self, X, y=None, sample_weight=None):
#    1233     """Compute cluster centers and predict cluster index for each sample.
#    1234
#    1235     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1253         Index of the cluster each sample belongs to.
#    1254     """
# -> 1255     return self.fit(X, sample_weight=sample_weight).labels_
#
# ...

# %%
#%% k = 3 icin modelim

kmeans2 = KMeans(n_clusters=2)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()

# %%
#%% k = 3 icin modelim

kmeans2 = KMeans(n_clusters=3)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()

# %%
#%% k = 3 icin modelim

kmeans2 = KMeans(n_clusters=4)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")
plt.scatter(data.x[data.label == 3 ],data.y[data.label == 3],color = "pink")
plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()

# %%
#%% k = 3 icin modelim

kmeans2 = KMeans(n_clusters=5)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")
plt.scatter(data.x[data.label == 3 ],data.y[data.label == 3],color = "gray")
plt.scatter(data.x[data.label == 4 ],data.y[data.label == 4],color = "black")

plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()

# %%
#%% k = 3 icin modelim

kmeans2 = KMeans(n_clusters=10)
clusters = kmeans2.fit_predict(data)

data["label"] = clusters

plt.scatter(data.x[data.label == 0 ],data.y[data.label == 0],color = "red")
plt.scatter(data.x[data.label == 1 ],data.y[data.label == 1],color = "green")
plt.scatter(data.x[data.label == 2 ],data.y[data.label == 2],color = "blue")
plt.scatter(data.x[data.label == 3 ],data.y[data.label == 3],color = "gray")
plt.scatter(data.x[data.label == 4 ],data.y[data.label == 4],color = "black")
plt.scatter(data.x[data.label == 5 ],data.y[data.label == 5],color = "gray")
plt.scatter(data.x[data.label == 6 ],data.y[data.label == 6],color = "black")
plt.scatter(data.x[data.label == 7 ],data.y[data.label == 7],color = "gray")
plt.scatter(data.x[data.label == 8 ],data.y[data.label == 8],color = "black")
plt.scatter(data.x[data.label == 9 ],data.y[data.label == 9],color = "black")

plt.scatter(kmeans2.cluster_centers_[:,0],kmeans2.cluster_centers_[:,1],color = "yellow")
plt.show()
